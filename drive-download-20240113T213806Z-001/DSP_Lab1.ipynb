# %%
x=5
y=7
print(x^y)
# Out:
# 2

# %%
x=[12,0,-3,44,2,11]
for a in range(len(x)):
  for b in range(len(x)-1):
    if x[a]<x[b]:
      c=x[a]+x[b]
      x[b]=c-x[b]
      x[a]=c-x[a]
print(x)
# Out:
# [-3, 0, 2, 11, 12, 44]
